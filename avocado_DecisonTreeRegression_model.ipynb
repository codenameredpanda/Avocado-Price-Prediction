# %% [markdown]
# # Decision Tree Regression Model

# %% [markdown]
# This notebook is for a decision tree regression model.
#
# The highest r2 is .66

# %%
# importing libraries
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import psycopg2
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## Importing data

# %%
# creating an engine to connect to postgres
# need to add .gitignore for password
engine = create_engine('postgresql+psycopg2://postgres:gitignore@localhost/Avocados')

# %%
# reflecting Database into ORM classes
Base = automap_base()
Base.prepare(autoload_with=engine)
Base.classes.keys()
# Out:
# ['region', 'type', 'market', 'avocados']

# %%
# creating a session
session = Session(engine)

# %%
# creating our classes for each table in our 'Avocado' Database
avocados = Base.classes.avocados
market = Base.classes.market
type = Base.classes.type
region = Base.classes.region

# %%
# we used the 'read_sql' and 'join' function to merge all of our tables into one and created a pandas DataFrame
avocado_df = pd.read_sql(session.query(avocados, region, type, market)
                         .join(region, region.index == avocados.region_)
                         .join(market, market.index == avocados.market_)
                         .join(type, type.index == avocados.type_).statement, session.bind)
avocado_df.head(10)
# Out:
#    index        date  averageprice  totalvolume    plu4046    plu4225  \
# 0      0  2015-01-04          1.22     40873.28    2819.50   28287.42
# 1      1  2015-01-04          1.79      1373.95      57.42     153.88
# 2      2  2015-01-04          1.00    435021.49  364302.39   23821.16
# 3      3  2015-01-04          1.76      3846.69    1500.15     938.35
# 4      4  2015-01-04          1.08    788025.06   53987.31  552906.04
# 5      5  2015-01-04          1.29     19137.28    8040.64    6557.47
# 6      6  2015-01-04          1.01     80034.32   44562.12   24964.23
# 7      7  2015-01-04          1.64      1505.12       1.27    1129.50
# 8      8  2015-01-04          1.02    491738.00    7193.87  396752.18
# 9      9  2015-01-04          1.83      2192.13       8.66     939.43
#
#     plu4770  totalbags  smallbags  largebags  xlargebags  type_  region_  \
# 0     49.90    9716.46    9186.93     529.53         0.0      0        0
# 1      0.00    1162.65    1162.65       0.00         0.0      1        0
# 2     82.15   46815.79   16707.15   30108.64         0.0      0        1
# 3      0.00    1408.19    1071.35     336.84         0.0      1        1
# 4  39995.03  141136.68  137146.07    3990.61         0.0      0        2
# 5    657.48    3881.69    3881.69       0.00         0.0      1        2
# 6   2752.35    7755.62    6064.30    1691.32         0.0      0        3
# 7      0.00     374.35     186.67     187.68         0.0      1        3
# 8    128.82   87663.13   87406.84     256.29         0.0      0        4
# 9      0.00    1244.04    1244.04       0.00         0.0      1        4
#
#    market_  index_1               region  index_2          type  index_3  \
# 0        0        0               Albany        0  conventional        0
# 1        0        0               Albany        1       organic        0
# 2        1        1              Atlanta        0  conventional        1
# 3        1        1              Atlanta        1       organic        1
# 4        2        2  BaltimoreWashington        0  conventional        2
# 5        2        2  BaltimoreWashington        1       organic        2
# 6        3        3                Boise        0  conventional        3
# 7        3        3                Boise        1       organic        3
# 8        0        4               Boston        0  conventional        0
# 9        0        4               Boston        1       organic        0
#
#       market
# 0  northeast
# 1  northeast
# 2  southeast
# 3  southeast
# 4   midsouth
# 5   midsouth
# 6       west
# 7       west
# 8  northeast
# 9  northeast

# %%
# remove unneccessary columns
avocado_df = avocado_df.drop(columns=['type_', 'region_', 'market_', 'index_1', 'index_2', 'index_3'])
avocado_df.head(10)
# Out:
#    index        date  averageprice  totalvolume    plu4046    plu4225  \
# 0      0  2015-01-04          1.22     40873.28    2819.50   28287.42
# 1      1  2015-01-04          1.79      1373.95      57.42     153.88
# 2      2  2015-01-04          1.00    435021.49  364302.39   23821.16
# 3      3  2015-01-04          1.76      3846.69    1500.15     938.35
# 4      4  2015-01-04          1.08    788025.06   53987.31  552906.04
# 5      5  2015-01-04          1.29     19137.28    8040.64    6557.47
# 6      6  2015-01-04          1.01     80034.32   44562.12   24964.23
# 7      7  2015-01-04          1.64      1505.12       1.27    1129.50
# 8      8  2015-01-04          1.02    491738.00    7193.87  396752.18
# 9      9  2015-01-04          1.83      2192.13       8.66     939.43
#
#     plu4770  totalbags  smallbags  largebags  xlargebags               region  \
# 0     49.90    9716.46    9186.93     529.53         0.0               Albany
# 1      0.00    1162.65    1162.65       0.00         0.0               Albany
# 2     82.15   46815.79   16707.15   30108.64         0.0              Atlanta
# 3      0.00    1408.19    1071.35     336.84         0.0              Atlanta
# 4  39995.03  141136.68  137146.07    3990.61         0.0  BaltimoreWashington
# 5    657.48    3881.69    3881.69       0.00         0.0  BaltimoreWashington
# 6   2752.35    7755.62    6064.30    1691.32         0.0                Boise
# 7      0.00     374.35     186.67     187.68         0.0                Boise
# 8    128.82   87663.13   87406.84     256.29         0.0               Boston
# 9      0.00    1244.04    1244.04       0.00         0.0               Boston
#
#            type     market
# 0  conventional  northeast
# 1       organic  northeast
# 2  conventional  southeast
# 3       organic  southeast
# 4  conventional   midsouth
# 5       organic   midsouth
# 6  conventional       west
# 7       organic       west
# 8  conventional  northeast
# 9       organic  northeast

# %% [markdown]
# ## Preprocesing

# %%
# change date to datetime for pandas
avocado_df['date'] = pd.to_datetime(avocado_df['date'])
avocado_df.dtypes
# Out:
# index                    int64
# date            datetime64[ns]
# averageprice           float64
# totalvolume            float64
# plu4046                float64
# plu4225                float64
# plu4770                float64
# totalbags              float64
# smallbags              float64
# largebags              float64
# xlargebags             float64
# region                  object
# type                    object
# market                  object
# dtype: object

# %%
# extract the month from the date to easily bin
avocado_df['month'] = pd.DatetimeIndex(avocado_df['date']).month
avocado_df
# Out:
#        index       date  averageprice  totalvolume    plu4046    plu4225  \
# 0          0 2015-01-04      1.220000     40873.28    2819.50   28287.42
# 1          1 2015-01-04      1.790000      1373.95      57.42     153.88
# 2          2 2015-01-04      1.000000    435021.49  364302.39   23821.16
# 3          3 2015-01-04      1.760000      3846.69    1500.15     938.35
# 4          4 2015-01-04      1.080000    788025.06   53987.31  552906.04
# ...      ...        ...           ...          ...        ...        ...
# 45022  53408 2023-12-03      1.616528      4947.25     154.75     194.69
# 45023  53409 2023-12-03      1.421139     24520.55     222.70      91.35
# 45024  53410 2023-12-03      1.550513      5693.91     204.64    1211.25
# 45025  53412 2023-12-03      1.618931     34834.86   15182.42    1211.38
# 45026  53413 2023-12-03      1.245406      2942.83    1058.54       7.46
#
#         plu4770  totalbags  smallbags  largebags  xlargebags  \
# 0         49.90    9716.46    9186.93     529.53         0.0
# 1          0.00    1162.65    1162.65       0.00         0.0
# 2         82.15   46815.79   16707.15   30108.64         0.0
# 3          0.00    1408.19    1071.35     336.84         0.0
# 4      39995.03  141136.68  137146.07    3990.61         0.0
# ...         ...        ...        ...        ...         ...
# 45022      0.00    4475.54        NaN        NaN         NaN
# 45023      0.00   24206.50        NaN        NaN         NaN
# 45024      0.00    4278.03        NaN        NaN         NaN
# 45025      0.00   18075.66        NaN        NaN         NaN
# 45026      0.00    1779.19        NaN        NaN         NaN
#
#                     region          type       market  month
# 0                   Albany  conventional    northeast      1
# 1                   Albany       organic    northeast      1
# 2                  Atlanta  conventional    southeast      1
# 3                  Atlanta       organic    southeast      1
# 4      BaltimoreWashington  conventional     midsouth      1
# ...                    ...           ...          ...    ...
# 45022             Syracuse       organic    northeast     12
# 45023                Tampa       organic    southeast     12
# 45024               Toledo       organic  great_lakes     12
# 45025     WestTexNewMexico       organic         west     12
# 45026              Wichita       organic       plains     12
#
# [45027 rows x 15 columns]

# %%
# create bins to move date to quarters, making them usable data points in the regression model
bins = [0, 3, 6, 9, 12]
# labels of bins 
labels = ['Q1', 'Q2', 'Q3', 'Q4']
# bin the data using the month column created above
avocado_df['quarter'] = pd.cut(avocado_df['month'], bins=bins, labels=labels)
# drop the unneccessary columns
avocado_df=avocado_df.drop(columns=['date', 'month'])
# cast quarter column to string for dummies to work
avocado_df['quarter'] = avocado_df['quarter'].astype(str)
avocado_df.dtypes
# Out:
# index             int64
# averageprice    float64
# totalvolume     float64
# plu4046         float64
# plu4225         float64
# plu4770         float64
# totalbags       float64
# smallbags       float64
# largebags       float64
# xlargebags      float64
# region           object
# type             object
# market           object
# quarter          object
# dtype: object

# %%
# drop the index to remove unique data
avocado_df = avocado_df.drop(columns=['index'])
avocado_df
# Out:
#        averageprice  totalvolume    plu4046    plu4225   plu4770  totalbags  \
# 0          1.220000     40873.28    2819.50   28287.42     49.90    9716.46
# 1          1.790000      1373.95      57.42     153.88      0.00    1162.65
# 2          1.000000    435021.49  364302.39   23821.16     82.15   46815.79
# 3          1.760000      3846.69    1500.15     938.35      0.00    1408.19
# 4          1.080000    788025.06   53987.31  552906.04  39995.03  141136.68
# ...             ...          ...        ...        ...       ...        ...
# 45022      1.616528      4947.25     154.75     194.69      0.00    4475.54
# 45023      1.421139     24520.55     222.70      91.35      0.00   24206.50
# 45024      1.550513      5693.91     204.64    1211.25      0.00    4278.03
# 45025      1.618931     34834.86   15182.42    1211.38      0.00   18075.66
# 45026      1.245406      2942.83    1058.54       7.46      0.00    1779.19
#
#        smallbags  largebags  xlargebags               region          type  \
# 0        9186.93     529.53         0.0               Albany  conventional
# 1        1162.65       0.00         0.0               Albany       organic
# 2       16707.15   30108.64         0.0              Atlanta  conventional
# 3        1071.35     336.84         0.0              Atlanta       organic
# 4      137146.07    3990.61         0.0  BaltimoreWashington  conventional
# ...          ...        ...         ...                  ...           ...
# 45022        NaN        NaN         NaN             Syracuse       organic
# 45023        NaN        NaN         NaN                Tampa       organic
# 45024        NaN        NaN         NaN               Toledo       organic
# 45025        NaN        NaN         NaN     WestTexNewMexico       organic
# 45026        NaN        NaN         NaN              Wichita       organic
#
#             market quarter
# 0        northeast      Q1
# 1        northeast      Q1
# 2        southeast      Q1
# 3        southeast      Q1
# 4         midsouth      Q1
# ...            ...     ...
# 45022    northeast      Q4
# 45023    southeast      Q4
# 45024  great_lakes      Q4
# 45025         west      Q4
# 45026       plains      Q4
#
# [45027 rows x 13 columns]

# %% [markdown]
# ## Training the data

# %%
# here the number columns are scaled
# Instantiate a StandardScaler instance
scaler = StandardScaler()

# Fit the training data to the standard scaler
X_scaler = scaler.fit(avocado_df[['plu4046', 'plu4225', 'plu4770', 'totalbags']])

# Transform the training data using the scaler
scaled_data = X_scaler.transform(avocado_df[['plu4046', 'plu4225', 'plu4770', 'totalbags']])
avocado_df[['plu4046', 'plu4225', 'plu4770', 'totalbags']] = scaled_data

# %%
# define x and y here to avoid scaling the dummy data
# region and market represent the same data, so one of them must always be dropped

y = avocado_df['averageprice']

# test if market or region delivers better results
# this line to drop market (.66)
X = avocado_df.drop(columns=['averageprice', 'totalvolume', 'smallbags', 'largebags', 'xlargebags', 'market'])
# this line to drop region (.59)
#X = avocado_df.drop(columns=['averageprice', 'totalvolume', 'smallbags', 'largebags', 'xlargebags', 'region'])

# dropping market delivers better results. Market will be dropped on all other tests.
# this line to drop type (.67)
#X = avocado_df.drop(columns=['averageprice', 'totalvolume', 'smallbags', 'largebags', 'xlargebags', 'type'])
# this line to drop quarter (.62)
#X = avocado_df.drop(columns=['averageprice', 'totalvolume', 'smallbags', 'largebags', 'xlargebags', 'quarter'])
# this line to drop totalbags (.57)
#X = avocado_df.drop(columns=['averageprice', 'totalvolume', 'smallbags', 'largebags', 'xlargebags', 'totalbags'])
# this line to drop all bags (.56)
#X = avocado_df.drop(columns=['averageprice', 'totalvolume', 'totalbags', 'smallbags', 'largebags', 'xlargebags', 'market'])

# %%
X = pd.get_dummies(X)
X
# Out:
#         plu4046   plu4225   plu4770  totalbags  region_Albany  region_Atlanta  \
# 0     -0.459000 -0.271191 -0.217513  -0.481574           True           False
# 1     -0.474491 -0.462892 -0.219232  -0.554467           True           False
# 2      1.568360 -0.301624 -0.216402  -0.165422          False            True
# 3     -0.466399 -0.457547 -0.219232  -0.552375          False            True
# 4     -0.172028  3.303552  1.158317   0.638356          False           False
# ...         ...       ...       ...        ...            ...             ...
# 45022 -0.473945 -0.462614 -0.219232  -0.526235          False           False
# 45023 -0.473564 -0.463318 -0.219232  -0.358093          False           False
# 45024 -0.473665 -0.455687 -0.219232  -0.527919          False           False
# 45025 -0.389663 -0.455686 -0.219232  -0.410339          False           False
# 45026 -0.468876 -0.463890 -0.219232  -0.549213          False           False
#
#        region_BaltimoreWashington  region_BirminghamMontgomery  region_Boise  \
# 0                           False                        False         False
# 1                           False                        False         False
# 2                           False                        False         False
# 3                           False                        False         False
# 4                            True                        False         False
# ...                           ...                          ...           ...
# 45022                       False                        False         False
# 45023                       False                        False         False
# 45024                       False                        False         False
# 45025                       False                        False         False
# 45026                       False                        False         False
#
#        region_Boston  ...  region_Tampa  region_Toledo  \
# 0              False  ...         False          False
# 1              False  ...         False          False
# 2              False  ...         False          False
# 3              False  ...         False          False
# 4              False  ...         False          False
# ...              ...  ...           ...            ...
# 45022          False  ...         False          False
# 45023          False  ...          True          False
# 45024          False  ...         False           True
# 45025          False  ...         False          False
# 45026          False  ...         False          False
#
#        region_WestTexNewMexico  region_Wichita  type_conventional  \
# 0                        False           False               True
# 1                        False           False              False
# 2                        False           False               True
# 3                        False           False              False
# 4                        False           False               True
# ...                        ...             ...                ...
# 45022                    False           False              False
# 45023                    False           False              False
# 45024                    False           False              False
# 45025                     True           False              False
# 45026                    False            True              False
#
#        type_organic  quarter_Q1  quarter_Q2  quarter_Q3  quarter_Q4
# 0             False        True       False       False       False
# 1              True        True       False       False       False
# 2             False        True       False       False       False
# 3              True        True       False       False       False
# 4             False        True       False       False       False
# ...             ...         ...         ...         ...         ...
# 45022          True       False       False       False        True
# 45023          True       False       False       False        True
# 45024          True       False       False       False        True
# 45025          True       False       False       False        True
# 45026          True       False       False       False        True
#
# [45027 rows x 61 columns]

# %%
# this code helps clear away an unclear error
X= X.rename(str,axis="columns")

# %%
# Split the dataset using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ## Model

# %%
# Model training
model = DecisionTreeRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
# run evaluation metrics to test perfofmance of the model
mae = mean_absolute_error(y_test, y_pred) 
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
  
print("The mean absolute value is:",mae) 
print("The mean square error is:",mse) 
print("The root mean square error is:",rmse)
print("The R squared is:", r2)
# Out:
# The mean absolute value is: 0.15221504740241626
# The mean square error is: 0.05284956701195434
# The root mean square error is: 0.22989033692600988
# The R squared is: 0.6698805654279453

# %%
session.close()

# %% [markdown]
# ## Optional: Visualizing the decision tree

# %%
from sklearn.tree import export_graphviz
#import graphviz
import pydotplus
#from IPython.display import image

# %%
dot_data = export_graphviz(model, out_file=None, 
                           feature_names=X.columns,  
                           filled=True, rounded=True,  
                           special_characters=True)

# %%
graph = pydotplus.graph_from_dot_data(dot_data)

# %%
graph.write_png("dectree.png")
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.0175004 to fit
# True
